# %% [markdown]
# # Basic Example

# %% [markdown]
# This notebook contains a basic example of using Altair to make some visualizations.

# %% [markdown]
# ## Imports

# %%
import pandas
from altair import *

# %% [markdown]
# ## Load data

# %% [markdown]
# Load the iris data set:

# %%
iris = load_dataset('iris')

# %%
iris.head()
# Out:
#    petalLength  petalWidth  sepalLength  sepalWidth species
# 0          1.4         0.2          5.1         3.5  setosa
# 1          1.4         0.2          4.9         3.0  setosa
# 2          1.3         0.2          4.7         3.2  setosa
# 3          1.5         0.2          4.6         3.1  setosa
# 4          1.4         0.2          5.0         3.6  setosa

# %% [markdown]
# ## Visualization

# %% [markdown]
# First create a `Layer` object by passing in the data frame:

# %%
l = Layer(iris).encode(
    X('sepalLength'),
    Y('petalWidth'),
    Color('species')
).point()

# %%
l
# Out:
# <div class="vega-embed" id="634cfe00-715c-49ab-b7ef-28b3e56cb418"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>
