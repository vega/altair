# %% [markdown]
# # Scatterplot

# %% [markdown]
# ## Imports

# %%
from altair import *

# %% [markdown]
# ## Load dataset

# %%
data = load_dataset('cars')

# %%
data.head()
# Out:
#    Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
# 0          12.0          8           307         130                18
# 1          11.5          8           350         165                15
# 2          11.0          8           318         150                18
# 3          12.0          8           304         150                16
# 4          10.5          8           302         140                17
#
#                         Name Origin  Weight_in_lbs  Year
# 0  chevrolet chevelle malibu    USA           3504  1970
# 1          buick skylark 320    USA           3693  1970
# 2         plymouth satellite    USA           3436  1970
# 3              amc rebel sst    USA           3433  1970
# 4                ford torino    USA           3449  1970

# %% [markdown]
# ## Visualize

# %% [markdown]
# ```json
# {
#   "description": "A scatterplot showing horsepower and miles per gallons for various cars.",
#   "data": {"url": "data/cars.json"},
#   "mark": "point",
#   "encoding": {
#     "x": {"field": "Horsepower","type": "quantitative"},
#     "y": {"field": "Miles_per_Gallon","type": "quantitative"}
#   }
# }
# ```

# %%
Layer(data).encode(
    x=X('Horsepower'),
    y=Y('Miles_per_Gallon')
).point()
# Out:
# <div class="vega-embed" id="441a6dd8-160a-49ee-8cbe-850305e77ecf"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>
