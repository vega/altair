# %% [markdown]
# # Scatterplot with filled circles
#
# *Notebook auto-generated from ``altair/examples/scatterplot_with_filled_circles.py``*

# %%
from altair.api import *
import altair.datasets as ds

# %% [markdown]
# ## Load Dataset

# %%
data = ds.load_dataset('cars')

# %%
data.head()
# Out:
#    Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
# 0          12.0          8         307.0       130.0              18.0
# 1          11.5          8         350.0       165.0              15.0
# 2          11.0          8         318.0       150.0              18.0
# 3          12.0          8         304.0       150.0              16.0
# 4          10.5          8         302.0       140.0              17.0
#
#                         Name Origin  Weight_in_lbs  Year
# 0  chevrolet chevelle malibu    USA           3504  1970
# 1          buick skylark 320    USA           3693  1970
# 2         plymouth satellite    USA           3436  1970
# 3              amc rebel sst    USA           3433  1970
# 4                ford torino    USA           3449  1970

# %% [markdown]
# ## Visualize Data

# %%
v = Layer().encode(
    x=X('Horsepower:Q'),
    y=Y('Miles_per_Gallon:Q')
).circle()

# %%
# generate vegalite spec:
v.to_dict()
# Out:
# {'encoding': {'x': {'field': 'Horsepower', 'type': 'quantitative'},
#   'y': {'field': 'Miles_per_Gallon', 'type': 'quantitative'}},
#  'mark': 'circle'}

# %%
from vega import vegalite
vegalite.view(data, v.to_dict())
# Out:
# <div class="vega-embed" data-type="vega-lite">{"config": {"cell": {"height": 350, "width": 500}}, "mark": "circle", "data": {"values": [{"Displacement": 307.0, "Acceleration": 12.0, "Weight_in_lbs": 3504, "Origin": "USA", "Year": 1970, "Name": "chevrolet chevelle malibu", "Horsepower": 130.0, "Miles_per_Gallon": 18.0, "Cylinders": 8}, {"Displacement": 350.0, "Acceleration": 11.5, "Weight_in_lbs": 3693, "Origin": "USA", "Year": 1970, "Name": "buick skylark 320", "Horsepower": 165.0, "Miles_per_Gallon": 15.0, "Cylinders": 8}, {"Displacement": 318.0, "Acceleration": 11.0, "Weight_in_lbs": 3436, "Origin": "USA", "Year": 1970, "Name": "plymouth satellite", "Horsepower": 150.0, "Miles_per_Gallon": 18.0, "Cylinders": 8}, {"Displacement": 304.0, "Acceleration": 12.0, "Weight_in_lbs": 3433, "Origin": "USA", "Year": 1970, "Name": "amc rebel sst", "Horsepower": 150.0, "Miles_per_Gallon": 16.0, "Cylinders": 8}, {"Displacement": 302.0, "Acceleration": 10.5, "Weight_in_lbs": 3449, "Origin": "USA",
# ...
