# %% [markdown]
# # Scatterplot
#
# *Notebook auto-generated from ``altair/examples/scatterplot.py``*

# %%
from altair import *

# %% [markdown]
# ## Load Dataset

# %%
data = load_dataset('cars')

# %%
data.head()
# Out:
#    Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
# 0          12.0          8           307         130                18
# 1          11.5          8           350         165                15
# 2          11.0          8           318         150                18
# 3          12.0          8           304         150                16
# 4          10.5          8           302         140                17
#
#                         Name Origin  Weight_in_lbs  Year
# 0  chevrolet chevelle malibu    USA           3504  1970
# 1          buick skylark 320    USA           3693  1970
# 2         plymouth satellite    USA           3436  1970
# 3              amc rebel sst    USA           3433  1970
# 4                ford torino    USA           3449  1970

# %% [markdown]
# ## Visualize Data

# %%
v = Layer().encode(
    x=X('Horsepower:Q'),
    y=Y('Miles_per_Gallon:Q')
).point()

# %%
# generate vegalite spec:
v.to_dict()
# Out:
# {'encoding': {'x': {'field': 'Horsepower', 'type': 'quantitative'},
#   'y': {'field': 'Miles_per_Gallon', 'type': 'quantitative'}},
#  'mark': 'point'}

# %%
from vega import vegalite
vegalite.view(data, v.to_dict())
# Out:
# <div class="vega-embed" data-type="vega-lite">{"mark": "point", "config": {"cell": {"height": 350, "width": 500}}, "encoding": {"y": {"field": "Miles_per_Gallon", "type": "quantitative"}, "x": {"field": "Horsepower", "type": "quantitative"}}, "data": {"values": [{"Origin": "USA", "Horsepower": 130.0, "Cylinders": 8, "Miles_per_Gallon": 18.0, "Weight_in_lbs": 3504, "Displacement": 307.0, "Year": 1970, "Acceleration": 12.0, "Name": "chevrolet chevelle malibu"}, {"Origin": "USA", "Horsepower": 165.0, "Cylinders": 8, "Miles_per_Gallon": 15.0, "Weight_in_lbs": 3693, "Displacement": 350.0, "Year": 1970, "Acceleration": 11.5, "Name": "buick skylark 320"}, {"Origin": "USA", "Horsepower": 150.0, "Cylinders": 8, "Miles_per_Gallon": 18.0, "Weight_in_lbs": 3436, "Displacement": 318.0, "Year": 1970, "Acceleration": 11.0, "Name": "plymouth satellite"}, {"Origin": "USA", "Horsepower": 150.0, "Cylinders": 8, "Miles_per_Gallon": 16.0, "Weight_in_lbs": 3433, "Displacement": 304.0, "Year": 1970, "Acceleration": 12.0, "Name": "amc rebel sst"}, {"Origin": "USA", "Horsepower": 140.0, "Cylinders": 8, "Miles_per_Gallon": 17.0, "Weight_in_lbs": 3449, "Displacement": 302.0, "Year": 1970, "Acceleration": 10.5, "Name": "ford torino"}, {"Origin": "USA", "Horsepower": 198.0, "Cylinders": 8, "Miles_per_Gallon": 15.0, "Weight_in_lbs": 4341, "Displacement": 429.0, "Year": 1970, "Acceleration": 10.0, "Name": "ford galaxie 500"}, {"Origin": "USA", "Horsepower": 220.0, "Cylinders": 8, "Miles_per_Gallon": 14.0, "Weight_in_lbs": 4354, "Displacement": 454.0, "Year": 1970, "Acceleration": 9.0, "Name": "chevrolet impala"}, {"Origin": "USA", "Horsepower": 215.0, "Cylinders": 8, "Miles_per_Gallon": 14.0, "Weight_in_lbs": 4312, "Displacement": 440.0, "Year": 1970, "Acceleration": 8.5, "Name": "plymouth fury iii"}, {"Origin": "USA", "Horsepower": 225.0, "Cylinders": 8, "Miles_per_Gallon": 14.0, "Weight_in_lbs": 4425, "Displacement": 455.0, "Year": 1970, "Acceleration": 10.0, "Name": "pontiac catalina"}, {"Origin": "USA", "Horsepower": 190.0, "Cylinders": 8, "Miles_per_Gallon": 15.0, "Weight_in_lbs": 3850, "Displacement": 390.0, "Year": 1970, "Acceleration": 8.5, "Name": "amc ambassador dpl"}, {"Origin": "Europe", "Horsepower": 115.0, "Cylinders": 4, "Miles_per_Gallon": null, "Weight_in_lbs": 3090, "Displacement": 133.0, "Year": 1970, "Acceleration": 17.5, "Name": "citroen ds-21 pallas"}, {"Origin": "USA", "Horsepower": 165.0, "Cylinders": 8, "Miles_per_Gallon": null, "Weight_in_lbs": 4142, "Displacement": 350.0, "Year": 1970, "Acceleration": 11.5, "Name": "chevrolet chevelle concours (sw)"}, {"Origin": "USA", "Horsepower": 153.0, "Cylinders": 8, "Miles_per_Gallon": null, "Weight_in_lbs": 4034, "Displacement": 351.0, "Year": 1970, "Acceleration": 11.0, "Name": "ford torino (sw)"}, {"Origin": "USA", "Horsepower": 175.0, "Cylinders": 8, "Miles_per_Gallon": null, "Weight_in_lbs": 4166, "Displacement": 383.0, "Year": 1970, "Acceleration": 10.5, "Name": "plymouth satellite (sw)"}, {"Origin": "USA", "Horsepower": 175.0, "Cylinders": 8, "Miles_per_Gallon": null, "Weight_in_lbs": 3850, "Displacement": 360.0, "Year": 1970, "Acceleration": 11.0, "Name": "amc rebel sst (sw)"}, {"Origin": "USA", "Horsepower": 170.0, "Cylinders": 8, "Miles_per_Gallon": 15.0, "Weight_in_lbs": 3563, "Displacement": 383.0, "Year": 1970, "Acceleration": 10.0, "Name": "dodge challenger se"}, {"Origin": "USA", "Horsepower": 160.0, "Cylinders": 8, "Miles_per_Gallon": 14.0, "Weight_in_lbs": 3609, "Displacement": 340.0, "Year": 1970, "Acceleration": 8.0, "Name": "plymouth 'cuda 340"}, {"Origin": "USA", "Horsepower": 140.0, "Cylinders": 8, "Miles_per_Gallon": null, "Weight_in_lbs": 3353, "Displacement": 302.0, "Year": 1970, "Acceleration": 8.0, "Name": "ford mustang boss 302"}, {"Origin": "USA", "Horsepower": 150.0, "Cylinders": 8, "Miles_per_Gallon": 15.0, "Weight_in_lbs": 3761, "Displacement": 400.0, "Year": 1970, "Acceleration": 9.5, "Name": "chevrolet monte carlo"}, {"Origin": "USA", "Horsepower": 225.0, "C ...
