# %% [markdown]
# # Area Charts

# %%
from altair import *

# %%
data = load_dataset('unemployment-across-industries')
data['date'] = data['date'].astype(str)

# %% [markdown]
# ## Simple Area Chart

# %%
Chart(data).mark_area().encode(
    X('date:T', axis=Axis(format='%Y', labelAngle=0)),
    y='sum(count)'
)
# Out:
# <div class="vega-embed" id="ec442172-cd47-480b-80d7-26062a4a282a"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Stacked Area Chart

# %%
Chart(data).mark_area().encode(
    X('date:T',
      timeUnit='yearmonth',
      axis=Axis(format='%Y', labelAngle=0, title='year')),
    Y('sum(count)'),
    Color('series:N', scale=Scale(range="category20b"))
)
# Out:
# <div class="vega-embed" id="81dab22d-4aed-4beb-9b09-e127c9c2a5f9"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Normalized Area Chart

# %%
Chart(data).mark_area(stacked='normalize').encode(
    X('date:T', timeUnit='yearmonth',
      axis=Axis(format='%Y', labelAngle=0, title='year')),
    Y('sum(count)'),
    color=Color('series:N', scale=Scale(range="category20b"))
)
# Out:
# <div class="vega-embed" id="567c9292-8fd8-44ab-80a0-289ff3262bd8"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## SteamGraph

# %%
Chart(data).mark_area(stacked='center').encode(
    X('date:T', timeUnit='yearmonth',
      axis=Axis(format='%Y', labelAngle=0, title='year')),
    Y('sum(count)'),
    color=Color('series:N', scale=Scale(range="category20b"))
)
# Out:
# <div class="vega-embed" id="392c1715-9057-493e-8e0a-af6e8ee94631"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>
