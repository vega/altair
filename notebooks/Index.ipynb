# %% [markdown]
# # Altair Documentation
#
# [Altair](http://github.com/ellisonbg/altair/) is a module for declarative data visualization in Python, built on top of [Vega-Lite](http://vega.github.io/vega-lite/).
# From the Vega-lite documentation:
#
# > Vega-Lite specifications describe visualizations as mappings from data to **properties of graphical marks** (e.g., points or bars). It **automatically produces visualization components** including axes, legends, and scales. It then determines properties of these components based on a set of **carefully designed rules**. This approach allows Vega-Lite specifications to be succinct and expressive, but also provide user control. As Vega-Lite is designed for analysis, it supports **data transformations** such as aggregation, binning, filtering, sorting, and **visual transformations** including stacking and faceting.
#
# The key feature of this declarative approach is that the user is free to think about the data, rather than the mechanics of the visualization.
# Vega-lite specifications are expressed in JavaScript Object Notation (JSON), a cross-platform format often used for storage of nested and/or hierarchical data.
# Altair builds a Python layer on top of this, so that rather than writing raw JSON strings the user can write declarative Python code.

# %% [markdown]
# ## Quick Altair Example
#
# Here is a quick example of the Altair API in action:

# %%
from altair import datasets, Layer

data = datasets.load_dataset('cars')

Layer(data).encode(
          x='Horsepower',
          y='Miles_per_Gallon',
          color='Origin',
    ).circle()
# Out:
# <div class="vega-embed" id="83863df3-b0e9-4761-8ebd-21be8cadf1da"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# In most cases, the data passed to the ``Layer`` will be a standard Pandas dataframe, as we can see here:

# %%
data.head()
# Out:
#    Acceleration  Cylinders  Displacement  Horsepower  Miles_per_Gallon  \
# 0          12.0          8         307.0       130.0              18.0
# 1          11.5          8         350.0       165.0              15.0
# 2          11.0          8         318.0       150.0              18.0
# 3          12.0          8         304.0       150.0              16.0
# 4          10.5          8         302.0       140.0              17.0
#
#                         Name Origin  Weight_in_lbs  Year
# 0  chevrolet chevelle malibu    USA           3504  1970
# 1          buick skylark 320    USA           3693  1970
# 2         plymouth satellite    USA           3436  1970
# 3              amc rebel sst    USA           3433  1970
# 4                ford torino    USA           3449  1970

# %% [markdown]
# Under the hood, Altair interprets the input and constructs a Python dictionary of the vega spec:

# %%
Out[1].to_dict(data=False)
# Out:
# {'encoding': {'color': {'field': 'Origin', 'type': 'nominal'},
#   'x': {'field': 'Horsepower', 'type': 'quantitative'},
#   'y': {'field': 'Miles_per_Gallon', 'type': 'quantitative'}},
#  'mark': 'circle'}

# %% [markdown]
# When converted to JSON, this spec is exactly in the form expected by Vega-Lite.

# %% [markdown]
# ## Further Examples
#
# 1. [Scatter Plots](ScatterPlots.ipynb)
# 2. [Bar Charts](BarCharts.ipynb)
# 3. [Line Plots](LinePlots.ipynb)
# 4. [Area Plots](AreaPlots.ipynb)
#
# The remainder of the documentation is in a set of notebooks diving into the use of Altair:
#
# *Coming Soon:*
#
# 1. Encodings
# 2. Plot Types
# 1. BasicConcepts
# 4. Data Transformations
# 5. Plot Configuration
# 6. Examples
