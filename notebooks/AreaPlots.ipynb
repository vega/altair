# %% [markdown]
# # Area Plots

# %%
from altair import *

# %%
data = load_dataset('unemployment-across-industries')
data['date'] = data['date'].astype(str)

# %% [markdown]
# ## Simple Area Chart

# %%
Layer(data).encode(
    X('date:T', axis=Axis(format='%Y', labelAngle=0.01)),
    y='sum(count)'
).area()
# Out:
# <div class="vega-embed" id="a0f41263-8544-4112-8089-24b0976c1eba"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Stacked Area Chart

# %%
Layer(data).encode(
    X('date:T',
      timeUnit='yearmonth',
      axis=Axis(format='%Y', labelAngle=0.01)),
    Y('sum(count)'),
    Color('series:N', scale=Scale(range="category20b"))
).area()
# Out:
# <div class="vega-embed" id="96eec5ed-4c03-474b-ae5e-81572ddbdedb"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Normalized Area Chart

# %%
Layer(data).encode(
    X('date:T', timeUnit='yearmonth',
      axis=Axis(format='%Y', labelAngle=0.01)),
    Y('sum(count)'),
    color=Color('series:N', scale=Scale(range="category20b"))
).configure(
    mark=MarkConfig(stacked='normalize')  
).area()
# Out:
# <div class="vega-embed" id="e0910fe7-62fe-48ce-8f42-8ecfaf42cfcb"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## SteamGraph

# %%
Layer(data).encode(
    X('date:T', timeUnit='yearmonth',
      axis=Axis(format='%Y', labelAngle=0.01)),
    Y('sum(count)'),
    color=Color('series:N', scale=Scale(range="category20b"))
).configure(
    mark=MarkConfig(stacked='center')  
).area()
# Out:
# <div class="vega-embed" id="d10e8c3a-bf08-4e42-98a6-366118f70f42"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>
