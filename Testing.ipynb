# %%
import altair.api as spec
from altair.mpl import render
# %matplotlib notebook
import pandas

# %%
df = {'year':list(range(10)),'amount':list(range(10))}

# %%
v = spec.Viz(df).encode(x='year:T',y='amount',row='gender:N').mark_point()

# %%
v.encoding.y.bin = 10
v.encoding.x.aggregate = None

# %%
render(v)
# Out:
#    amount  year
# 0     NaN     0
# 1    1.35     1
# 2    2.25     2
# 3    3.15     3
# 4    4.05     4
# 5    4.95     5
# 6    5.85     6
# 7    6.75     7
# 8    7.65     8
# 9    8.55     9
# <img src="data:image/png;base64,...">
# (<matplotlib.lines.Line2D at 0x108c8cf28>,)
