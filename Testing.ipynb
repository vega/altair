# %%
import altair.api as spec
from altair.mpl import render

import pandas
import seaborn.apionly as sns

# %matplotlib notebook

# %%
iris = sns.load_dataset('iris')

# %%
v = spec.Viz(iris).encode(x='sepal_length',y='petal_width',shape=spec.Shape(name='sepal_width', filled=True), row='species').mark_point()
# Out:
# /home/tcaswell/.virtualenvs/dd_py3k/lib/python3.4/site-packages/pandas/core/internals.py:956: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   return self._try_coerce_result(func(values, other))

# %%
render(v)
# Out:
# <img src="data:image/png;base64,...">
# ({'setosa': [<matplotlib.lines.Line2D at 0x7f079212a828>,
#    <matplotlib.lines.Line2D at 0x7f079212ab38>,
#    <matplotlib.lines.Line2D at 0x7f0792116be0>,
#    <matplotlib.lines.Line2D at 0x7f079214a780>,
#    <matplotlib.lines.Line2D at 0x7f079212fac8>,
#    <matplotlib.lines.Line2D at 0x7f07920b8320>,
#    <matplotlib.lines.Line2D at 0x7f07920b8b38>,
#    <matplotlib.lines.Line2D at 0x7f079212aa20>,
#    <matplotlib.lines.Line2D at 0x7f07920bd978>,
#    <matplotlib.lines.Line2D at 0x7f07920c31d0>,
#    <matplotlib.lines.Line2D at 0x7f07920c3a20>,
#    <matplotlib.lines.Line2D at 0x7f07920c9278>,
#    <matplotlib.lines.Line2D at 0x7f07920c9a90>],
#   'versicolor': [<matplotlib.lines.Line2D at 0x7f07920cfa90>,
#    <matplotlib.lines.Line2D at 0x7f07920d5278>,
#    <matplotlib.lines.Line2D at 0x7f0792188860>,
#    <matplotlib.lines.Line2D at 0x7f07920d5ac8>,
#    <matplotlib.lines.Line2D at 0x7f07920dc320>,
#    <matplotlib.lines.Line2D at 0x7f07920dca20>,
#    <matplotlib.lines.Line2D at 0x7f07920e01d0>,
#    <matplotlib.lines.Line2D at 0x7f07920e09e8>,
#    <matplotlib.lines.Line2D at 0x7f07920e7240>,
#    <matplotlib.lines.Line2D at 0x7f07920e7a58>,
#    <matplotlib.lines.Line2D at 0x7f07920e72e8>,
#    <matplotlib.lines.Line2D at 0x7f07920ee8d0>,
#    <matplotlib.lines.Line2D at 0x7f07920f2128>],
#   'virginica': [<matplotlib.lines.Line2D at 0x7f0792078358>,
#    <matplotlib.lines.Line2D at 0x7f0792078b00>,
#    <matplotlib.lines.Line2D at 0x7f079214da58>,
#    <matplotlib.lines.Line2D at 0x7f079207d1d0>,
#    <matplotlib.lines.Line2D at 0x7f079207d9e8>,
#    <matplotlib.lines.Line2D at 0x7f0792084240>,
#    <matplotlib.lines.Line2D at 0x7f0792084a58>,
#    <matplotlib.lines.Line2D at 0x7f079208c2b0>,
#    <matplotlib.lines.Line2D at 0x7f079208c9b0>,
#    <matplotlib.lines.Line2D at 0x7f0792090160>,
#    <matplotlib.lines.Line2D at 0x7f07920909b0>,
#    <matplotlib.lines.Line2D at 0x7f0792096208>,
#    <matplotlib.lines.Line2D at 0x7f0792096a20>]},
#  {'setosa': <matplotlib.axes._subplots.AxesSubplot at 0x7f07922a5a20>,
#   'versicolor': <matplotlib.axes._subplots.AxesSubplot at 0x7f07921b3f60>,
#   'virginica': <matplotlib.axes._subplots.AxesSubplot at 0x7f0792101278>})

# %%
ln.set_markerfacecolor('w')

# %%
# %debug
