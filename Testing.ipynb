# %%
import altair.api as spec
from altair.mpl import render
# %matplotlib notebook
import pandas

# %%
df = pandas.DataFrame({'year':list(range(10)),'amount':list(range(10)), 'klass':[0]*5 + [1]*5})

# %%
dd = list(df.groupby('klass'))[0]

# %%
v = spec.Viz(df).encode(x='year:T',y='amount',shape=spec.Shape(name='klass')).mark_point()
# Out:
# /home/tcaswell/.virtualenvs/dd_py3k/lib/python3.4/site-packages/pandas/core/internals.py:956: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   return self._try_coerce_result(func(values, other))

# %%
dd[0]
# Out:
# 0

# %%
v.encoding.y.bin = 10
v.encoding.x.aggregate = None

# %%
render(v)
# Out:
# <img src="data:image/png;base64,...">
# (0,    amount  klass  year
# 0     NaN      0     0
# 1    1.35      0     1
# 2    2.25      0     2
# 3    3.15      0     3
# 4    4.05      0     4)
# (1,    amount  klass  year
# 5    4.95      1     5
# 6    5.85      1     6
# 7    6.75      1     7
# 8    7.65      1     8
# 9    8.55      1     9)
# ...
