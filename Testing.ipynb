# %%
import altair.api as spec
from altair.mpl import render
# %matplotlib notebook
import pandas

# %%
df = {'year':list(range(10)),'amount':list(range(10))}

# %%
v = spec.Viz(df).encode(x='year:T',y='amount',row='gender:N').mark_point()

# %%
v.encoding.y.bin = 10
v.encoding.x.aggregate = None

# %%
render(v)
# Out:
#    amount  year
# 0     1.5     0
# 1     2.5     1
# 2     3.5     2
# 3     4.5     3
# 4     5.5     4
# 5     6.5     5
# 6     7.5     6
# 7     8.5     7
# 8     NaN     8
# 9     NaN     9
# <img src="data:image/png;base64,...">
# (<matplotlib.lines.Line2D at 0x7f18c97411d0>,)

# %%
# %debug

# %%
import matplotlib

# %%
matplotlib.__version__

# %%
# %debug

# %%
p
