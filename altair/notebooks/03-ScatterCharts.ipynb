# %% [markdown]
# # Scatter Chart Examples

# %%
from altair import *

# %%
cars = load_dataset('cars')

# %% [markdown]
# ## Dot chart

# %%
Chart(cars).mark_point().encode(
    x='Horsepower',
)
# Out:
# <div class="vega-embed" id="2d2821de-ef0c-43a1-be0f-86612b74f3d9"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Scatter chart

# %%
Chart(cars).mark_point().encode(
    x='Horsepower',
    y='Miles_per_Gallon'
)
# Out:
# <div class="vega-embed" id="34a8f001-408d-44bc-9539-ce770a1aa4ab"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Bubble chart

# %%
Chart(cars).mark_point().encode(
    x='Horsepower',
    y='Miles_per_Gallon',
    size='Acceleration'
)
# Out:
# <div class="vega-embed" id="ef59b6b2-2c51-42bc-8886-a116ad3f7166"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Scatter chart with color and/or shape

# %%
Chart(cars).mark_point().encode(
    x='Horsepower',
    y='Miles_per_Gallon',
    color='Origin',
    shape='Origin',
)
# Out:
# <div class="vega-embed" id="08530893-59c8-4ab5-981d-87802ac4d394"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Circle scatterchart

# %%
Chart(cars).mark_circle().encode(
    x='Horsepower',
    y='Miles_per_Gallon',
    color='Origin',
)
# Out:
# <div class="vega-embed" id="6f443c55-684b-4c5c-93f3-060a3e1214d3"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Square scatter chart

# %%
Chart(cars).mark_square().encode(
    x='Horsepower',
    y='Miles_per_Gallon',
    color='Origin',
)
# Out:
# <div class="vega-embed" id="9e1c5555-1eac-4883-913f-418105de08c9"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Text scatter chart

# %%
Chart(cars).mark_text().encode(
    x='Horsepower',
    y='Miles_per_Gallon',
    color='Origin',
    text='Origin'
)
# Out:
# <div class="vega-embed" id="cf7f06ff-aa99-4e98-abb1-924f572886f6"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Tick chart

# %%
Chart(cars).mark_tick().encode(
    x='Horsepower:Q',
    y='Cylinders:O',
)
# Out:
# <div class="vega-embed" id="36547962-2b73-4925-a53e-4a041f78c36f"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>
