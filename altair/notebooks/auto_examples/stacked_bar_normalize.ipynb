# %% [markdown]
# <small>*Notebook auto-generated from [``altair/examples/json/stacked_bar_normalize.vl.json``](../../altair/examples/json/stacked_bar_normalize.vl.json)*</small>
#
# # Altair Example: Stacked Bar Normalize
#
# --

# %% [markdown]
# ## Load Dataset
# The data comes in the form of a Pandas Dataframe:

# %%
from altair import load_dataset
data = load_dataset("population")
data.head()

# %% [markdown]
# ## Define Altair Specification

# %%
from altair import *  # Import the altair API

chart = Chart(data).mark_bar(
    stacked='normalize',
).encode(
    color=Color('gender:N',
        scale=Scale(
            range=['#EA98D2', '#659CCA'],
        ),
    ),
    x=X('age:O',
        scale=Scale(
            bandSize=17.0,
        ),
    ),
    y=Y('sum(people):Q',
        axis=Axis(
            title='population',
        ),
    ),
).transform_data(
    calculate=[Formula(
            expr='datum.sex == 2 ? "Female" : "Male"',
            field='gender',
        )],
    filter='datum.year == 2000',
)

# %% [markdown]
# IPython rich display will invoke Vega-Lite:

# %%
chart

# %% [markdown]
# ## Output Vega-Lite Specification

# %% [markdown]
# Generate JSON dict, leaving data out:

# %%
chart.to_dict(data=False)
