# %% [markdown]
# <small>*Notebook auto-generated from [``altair/examples/json/stacked_area_binned.vl.json``](../../altair/examples/json/stacked_area_binned.vl.json)*</small>
#
# # Altair Example: Stacked Area Binned
#
# --

# %% [markdown]
# ## Load Dataset
# The data comes in the form of a Pandas Dataframe:

# %%
from altair import load_dataset
data = load_dataset("cars")
data.head()

# %% [markdown]
# ## Define Altair Specification

# %%
from altair import *  # Import the altair API

chart = Chart(data).mark_area().encode(
    color='Cylinders:N',
    x=X('Acceleration:Q',
        bin=Bin(),
    ),
    y=Y('mean(Horsepower):Q',
        bin=False,
    ),
)

# %% [markdown]
# IPython rich display will invoke Vega-Lite:

# %%
chart

# %% [markdown]
# ## Output Vega-Lite Specification

# %% [markdown]
# Generate JSON dict, leaving data out:

# %%
chart.to_dict(data=False)
