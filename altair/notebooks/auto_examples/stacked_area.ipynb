# %% [markdown]
# <small>*Notebook auto-generated from [``altair/examples/json/stacked_area.vl.json``](../../altair/examples/json/stacked_area.vl.json)*</small>
#
# # Altair Example: Stacked Area
#
# Area chart showing weight of cars over time.

# %% [markdown]
# ## Load Dataset
# The data comes in the form of a Pandas Dataframe:

# %%
from altair import load_dataset
data = load_dataset("unemployment-across-industries")
data.head()

# %% [markdown]
# ## Define Altair Specification

# %%
from altair import *  # Import the altair API

chart = Chart(data).mark_area().encode(
    color=Color('series:N',
        scale=Scale(
            range='category20b',
        ),
    ),
    x=X('date:T',
        axis=Axis(
            axisWidth=0.0,
            format='%Y',
            labelAngle=0.0,
        ),
        scale=Scale(
            nice='month',
        ),
        timeUnit='yearmonth',
    ),
    y='sum(count):Q',
).configure_cell(
    height=200.0,
    width=300.0,
)

# %% [markdown]
# IPython rich display will invoke Vega-Lite:

# %%
chart

# %% [markdown]
# ## Output Vega-Lite Specification

# %% [markdown]
# Generate JSON dict, leaving data out:

# %%
chart.to_dict(data=False)
