# %% [markdown]
# <small>*Notebook auto-generated from [``altair/examples/json/scatter_color_ordinal_custom.vl.json``](../../altair/examples/json/scatter_color_ordinal_custom.vl.json)*</small>
#
# # Altair Example: Scatter Color Ordinal Custom
#
# --

# %% [markdown]
# ## Load Dataset
# The data comes in the form of a Pandas Dataframe:

# %%
from altair import load_dataset
data = load_dataset("cars")
data.head()

# %% [markdown]
# ## Define Altair Specification

# %%
from altair import *  # Import the altair API

chart = Chart(data).mark_point().encode(
    color=Color('Cylinders:O',
        scale=Scale(
            range=['pink', 'red'],
        ),
    ),
    x='Horsepower:Q',
    y='Miles_per_Gallon:Q',
)

# %% [markdown]
# IPython rich display will invoke Vega-Lite:

# %%
chart

# %% [markdown]
# ## Output Vega-Lite Specification

# %% [markdown]
# Generate JSON dict, leaving data out:

# %%
chart.to_dict(data=False)
