# %% [markdown]
# # Line Charts
#
# * [Simple line chart](#Simple-line-chart)
#     * [Data transform in Vega-Lite](#Data-transform-in-Vega-Lite)
#     * [Data transform in Pandas](#Data-transform-in-Pandas)
#     * [Log scale](#Log-scale)
# * [Grouped line chart](#Grouped-line-chart)
# * [Line chart with custom path](#Line-chart-with-custom-path)

# %%
from altair import *

# %%
data = load_dataset('stocks')

# %% [markdown]
# ## Simple line chart

# %% [markdown]
# ### Data transform in Vega-Lite

# %%
Chart(data).mark_line().encode(
    x='date:T',
    y='price:Q'
).transform_data(filter="datum.symbol==='GOOG'")
# Out:
# <div class="vega-embed" id="3c0905d7-306e-4c67-ba1a-c25c4404ea84"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ### Data transform in Pandas

# %%
Chart(data.query('symbol == "GOOG"')).mark_line().encode(
    x='date:T',
    y='price:Q'
)
# Out:
# <div class="vega-embed" id="25af4398-30ff-46b0-a8dd-35df6ca8774c"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ### Log scale

# %%
Chart(data.query('symbol == "GOOG"')).mark_line().encode(
    y=Y('price:Q', scale=Scale(type='log')),
    x='date:T',
)
# Out:
# <div class="vega-embed" id="504bf598-0e4e-49d3-b108-328ebfdeaaaa"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Grouped line chart

# %%
Chart(data).mark_line().encode(
    x='date:T',
    y='price',
    color='symbol',
)
# Out:
# <div class="vega-embed" id="f2356b94-2589-4d99-90d9-f1f6fe8c9ae0"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Line chart with custom path

# %%
data = load_dataset('driving')
Chart(data).mark_line().encode(
    X('miles', scale=Scale(zero=False)),
    Y('gas', scale=Scale(zero=False)),
    path='year:T',
)
# Out:
# <div class="vega-embed" id="00b7c400-6d17-4ff4-9a1f-326c28bc79b7"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>
