# %% [markdown]
# # Line Charts
#
# * [Simple line chart](#Simple-line-chart)
#     * [Data transform in Vega-Lite](#Data-transform-in-Vega-Lite)
#     * [Data transform in Pandas](#Data-transform-in-Pandas)
#     * [Log scale](#Log-scale)
# * [Grouped line chart](#Grouped-line-chart)
# * [Line chart with custom path](#Line-chart-with-custom-path)

# %%
from altair import *

# %%
data = load_dataset('stocks')

# %% [markdown]
# ## Simple line chart

# %% [markdown]
# ### Data transform in Vega-Lite

# %%
Chart(data).mark_line().encode(
    x='date:T',
    y='price:Q'
).transform_data(filter="datum.symbol==='GOOG'")
# Out:
# <div class="vega-embed" id="62508cd9-2c42-48d2-b03a-765e4e0b939a"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ### Data transform in Pandas

# %%
Chart(data.query('symbol == "GOOG"')).mark_line().encode(
    x='date:T',
    y='price:Q'
)
# Out:
# <div class="vega-embed" id="895c579e-4f65-4c5d-9243-a7feec54f277"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ### Log scale

# %%
Chart(data.query('symbol == "GOOG"')).mark_line().encode(
    y=Y('price:Q', scale=Scale(type='log')),
    x='date:T',
)
# Out:
# <div class="vega-embed" id="d0999bdb-9bc8-4b29-ae59-b141eeab70a7"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Grouped line chart

# %%
Chart(data).mark_line().encode(
    x='date:T',
    y='price',
    color='symbol',
)
# Out:
# <div class="vega-embed" id="2d52dc1e-0a08-46cb-a68a-ceb2958b8c26"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Line chart with custom path

# %%
data = load_dataset('driving')
Chart(data).mark_line().encode(
    X('miles', scale=Scale(zero=False)),
    Y('gas', scale=Scale(zero=False)),
    path='year:T',
)
# Out:
# <div class="vega-embed" id="3710cf97-3fc8-4951-a7f3-55a207c2ccac"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>
