# %% [markdown]
# # Line Charts

# %%
from altair import *

# %%
data = load_dataset('stocks')

# %% [markdown]
# ## Simple line chart

# %% [markdown]
# ### Data transform in Vega-Lite

# %%
Chart(data).mark_line().encode(
    x='date:T',
    y='price:Q'
).transform_data(filter="datum.symbol==='GOOG'")
# Out:
# <div class="vega-embed" id="9bc6923a-0f5c-4f0b-a060-bd32dafe7d43"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ### Data transform in Pandas

# %%
Chart(data.query('symbol == "GOOG"')).mark_line().encode(
    x='date:T',
    y='price:Q'
)
# Out:
# <div class="vega-embed" id="81e80e4d-84a0-484f-a9d8-b26e0d2f503b"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Grouped line chart

# %%
Chart(data).mark_line().encode(
    x='date:T',
    y='price',
    color='symbol',
)
# Out:
# <div class="vega-embed" id="d8de566b-b0f2-43e4-977a-dbc289153afc"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Line chart with custom path

# %%
data = load_dataset('driving')
Chart(data).mark_line().encode(
    X('miles', scale=Scale(zero=False)),
    Y('gas', scale=Scale(zero=False)),
    path='year:T',
)
# Out:
# <div class="vega-embed" id="e59d8e54-a776-4a83-879d-54c3522d3074"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>
