# %% [markdown]
# # Area Charts

# %%
from altair import *

# %%
data = load_dataset('unemployment-across-industries')
data['date'] = data['date'].astype(str)

# %% [markdown]
# ## Simple area chart

# %%
Chart(data).mark_area().encode(
    X('date:T', axis=Axis(format='%Y', labelAngle=0)),
    y='sum(count)'
)
# Out:
# <div class="vega-embed" id="c22cee60-ec8e-40a8-99ef-8ca4153bef54"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Stacked area chart

# %%
Chart(data).mark_area().encode(
    X('date:T',
      timeUnit='yearmonth',
      axis=Axis(format='%Y', labelAngle=0, title='year')),
    Y('sum(count)'),
    Color('series:N', scale=Scale(range="category20b"))
)
# Out:
# <div class="vega-embed" id="9ecfbbd3-b27d-4135-a6e0-9a23864a1df8"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Normalized area chart

# %%
Chart(data).mark_area(stacked='normalize').encode(
    X('date:T', timeUnit='yearmonth',
      axis=Axis(format='%Y', labelAngle=0, title='year')),
    Y('sum(count)'),
    color=Color('series:N', scale=Scale(range="category20b"))
)
# Out:
# <div class="vega-embed" id="155fdf60-fbc9-48a6-a12a-eec240859505"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# ## Streamgraph

# %%
Chart(data).mark_area(stacked='center').encode(
    X('date:T', timeUnit='yearmonth',
      axis=Axis(format='%Y', labelAngle=0, title='year')),
    Y('sum(count)'),
    color=Color('series:N', scale=Scale(range="category20b"))
)
# Out:
# <div class="vega-embed" id="be47522c-9b9e-4add-a7e7-674fbe60b1e3"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>
