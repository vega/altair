# %%
import numpy as np
import pandas as pd
from altair import api, html


def pairgrid_transform(data, rows, cols=None):
    """
    Transform a dataframe to allow vega to produce a PairGrid
    
    """
    if cols is None:
        cols = rows
      
    M1 = len(rows)
    M2 = len(cols)
    N = len(data)
    
    data = pd.concat(M1 * M2 * [data])
    i = np.arange(N * M1 * M2)
    irow = np.arange(N * M1 * M2) // N % M1
    icol = np.arange(N * M1 * M2) // N // M1
    
    data['x'] = data[cols].values[i, icol]
    data['y'] = data[rows].values[i, irow]
    data['row'] = rows.values[irow]
    data['col'] = cols.values[icol]
    
    return data

# %%
import seaborn as sns
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data = pairgrid_transform(iris, iris.columns[:4])
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species    x    y  \
# 0           5.1          3.5           1.4          0.2  setosa  5.1  5.1
# 1           4.9          3.0           1.4          0.2  setosa  4.9  4.9
# 2           4.7          3.2           1.3          0.2  setosa  4.7  4.7
# 3           4.6          3.1           1.5          0.2  setosa  4.6  4.6
# 4           5.0          3.6           1.4          0.2  setosa  5.0  5.0
#
#             row           col
# 0  sepal_length  sepal_length
# 1  sepal_length  sepal_length
# 2  sepal_length  sepal_length
# 3  sepal_length  sepal_length
# 4  sepal_length  sepal_length

# %%
from IPython.display import HTML

spec = api.Viz(data).encode(x='x', y='y', row='row', col='col', color='species').point()
html_out = html.render(spec)
HTML(html_out)
# Out:
# /Users/jakevdp/anaconda/envs/py3k/lib/python3.3/site-packages/pandas/core/internals.py:956: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   return self._try_coerce_result(func(values, other))
# <iframe width='500' height='300' frameBorder='0' srcdoc='
# <html>
#   <head>
#     <script src="http://vega.github.io/vega-editor/vendor/d3.min.js"></script>
#     <script src="http://vega.github.io/vega-editor/vendor/topojson.js"></script>
#     <script src="http://vega.github.io/vega-editor/vendor/d3.layout.cloud.js"></script>
#     <script src="http://rawgit.com/freeman-lab/vega-playground/master/js/vega.js"></script>
#     <script src="http://rawgit.com/freeman-lab/vega-playground/master/js/vega-lite.js"></script>
#   </head>
#   <body>
#     <div id="vis"></div>
#   </body>
#     <script type="text/javascript">
#       console.log(vg)
#
#       function parse(spec) {
#         vg.parse.spec(spec, function(chart) {
#           chart({el:"#vis"}).update();
#         });
#       }
#
#       function render(blob) {
#         var spec = vl.compile(blob);
#         parse(spec)
#       }
#       var data = {&#34;config&#34;: {&#34;width&#34;: 500, &#34;height&#34;: 300}, &#34;marktype&#34;: &#34;point&#34;, &#34;encoding&#34;: {&#34;color&#34;: {&#34;opacity&#34;: 1.0, &#34;value&#34;: &#34;#4682b4&#34;, &#34;bin&#34;: false, &#34;type&#34;: &#34;N&#34;, &#34;name&#34;: &#34;species&#34;}, &#34;x&#34;: {&#34;bin&#34;: false, &#34;type&#34;: &#34;Q&#34;, &#34;name&#34;: &#34;x&#34;}, &#34;y&#34;: {&#34;bin&#34;: false, &#34;type&#34;: &#34;Q&#34;, &#34;name&#34;: &#34;y&#34;}, &#34;row&#34;: {&#34;bin&#34;: false, &#34;padding&#34;: 0.1, &#34;height&#34;: 150, &#34;type&#34;: &#34;N&#34;, &#34;name&#34;: &#34;row&#34;}, &#34;col&#34;: {&#34;bin&#34;: false, &#34;padding&#34;: 0.1, &#34;height&#34;: 150, &#34;type&#34;: &#34;N&#34;, &#34;name&#34;: &#34;col&#34;}}, &#34;data&#34;: {&#34;formatType&#34;: &#34;json&#34;, &#34;values&#34;: [{&#34;y&#34;: 5.1, &#34;sepal_width&#34;: 3.5, &#34;petal_length&#34;: 1.4, &#34;species&#34;: &#34;setosa&#34;, &#34;petal_width&#34;: 0.2, &#34;col&#34;: &#34;sepal_length&#34;, &#34;sepal_length&#34;: 5.1, &#34;x&#34;: 5.1, &#34;row&#34;: &#34;sepal_length&#34;}, {&#34;y&#34;: 4.9, &#34;sepal_width&#34;: 3.0, &#34;petal_length&#34;: 1.4, &#34;species&#34;: &#34;setosa&#34;, &#34;petal_width&#34;: 0.2, &#34;col&#34;: &#34;sepal_length&#34;, &#34;sepal_length&#34;: 4.9, &#34;x&#34;: 4.9, &#34;row&#34;: &#34;sepal_length&#34;}, {&#34;y&#34;: 4.7, &#34;sepal_width&#34;: 3.2, &#34;petal_length&#34;: 1.3, &#34;species&#34;: &#34;setosa&#34;, &#34;petal_width&#34;: 0.2, &#34;col&#34;: &#34;sepal_length&#34;, &#34;sepal_length&#34;: 4.7, &#34;x&#34;: 4.7, &#34;row&#34;: &#34;sepal_length&#34;}, {&#34;y&#34;: 4.6, &#34;sepal_width&#34;: 3.1, &#34;petal_length&#34;: 1.5, &#34;species&#34;: &#34;setosa&#34;, &#34;petal_width&#34;: 0.2, &#34;col&#34;: &#34;sepal_length&#34;, &#34;sepal_length&#34;: 4.6, &#34;x&#34;: 4.6, &#34;row&#34;: &#34;sepal_length&#34;}, {&#34;y&#34;: 5.0, &#34;sepal_width&#34;: 3.6, &#34;petal_length&#34;: 1.4, &#34;species&#34;: &#34;setosa&#34;, &#34;petal_width&#34;: 0.2, &#34;col&#34;: &#34;sepal_length&#34;, &#34;sepal_length&#34;: 5.0, &#34;x&#34;: 5.0, &#34;row&#34;: &#34;sepal_length&#34;}, {&#34;y&#34;: 5.4, &#34;sepal_width&#34;: 3.9, &#34;petal_length&#34;: 1.7, &#34;species&#34;: &#34;setosa&#34;, &#34;petal_width&#34;: 0.4, &#34;col&#34;: &#34;sepal_length&#34;, &#34;sepal_length&#34;: 5.4, &#34;x&#34;: 5.4, &#34;row&#34;: &#34;sepal_length&#34;}, {&#34;y&#34;: 4.6, &#34;sepal_width&#34;: 3.4, &#34;petal_length&#34;: 1.4, &#34;species&#34;: &#34;setosa&#34;, &#34;petal_width&#34;: 0.3, &#34;col&#34;: &#34;sepal_length&#34;, &#34;sepal_length&#34;: 4.6, &#34;x&#34;: 4.6, &#34;row&#34;: &#34;sepal_length&#34;}, {&#34;y&#34;: 5.0, &#34;sepal_width&#34;: 3.4, &#34;petal_length&#34;: 1.5, &#34;species&#34;: &#34;setosa&#34;, &#34;petal_width&#34;: 0.2, &#34;col&#34;: &#34;sepal_length&#34;, &#34;sepal_length&#34;: 5.0, &#34;x&#34;: 5.0, &#34;row&#34;: &#34;sepal_length&#34;}, {&#34;y&#34;: 4.4, &#34;sepal_width&#34;: 2.9, &#34;petal_length&#34;: 1.4, &#34;species&#34;: &#34;setosa&#34;, &#34;petal_width&#34;: 0.2, &#34;col&#34;: &#34;sepal_length&#34;, &#34;sepal_length&#34;: 4.4, &#34;x&#34;: 4.4, &#34;row&#34;: &#34;sepal_length&#34;}, {&#34;y&#34;: 4.9, &#34;sepal_width&#34;: 3.1, &#34;petal_length&#34;: 1.5, &#34;species&#34;: &#34;setosa&#34;, &#34;petal_width&#34;: 0.1, &#34;col&#34;: &#34;sepal_length&#34;, &#34;sepal_length&#34;: 4.9, &#34;x&#34;: 4.9, &#34;row&#34;: &#34;sepal_length&#34;}, {&#34;y&#34;: 5.4, &#34;sepal_width&#34;: 3.7, &#34;petal_length&#34;: 1.5, &#34;species&#34;: &#34;setosa&#34;, &#34;petal_width&#34;: 0.2, &#34;col&#34;: &#34;sepal_length&#34;, &#34;sepal_length&#34;: 5.4, &#34;x&#34;: 5.4, &#34;row&#34;: &#34;sepal_length&#34;}, {&#34;y&#34;: 4.8, &#34;sepal_width&#34;: 3.4, &#34;petal_length&#34;: 1.6, &#34;species&#34;: &#34;setosa&#34;, &#34;petal_width&#34;: 0.2, &#34;col&#34;: &#34;sepal_length&#34;, &#34;sepal_length&#3 ...
